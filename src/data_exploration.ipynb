# %%
from utils.utility import get_labels
import pandas as pd

labels_df = get_labels("train")
print(labels_df.shape)

train = pd.read_csv("/home/fabri/PoseBowl/SpacecraftDetection/dataset/train1_labels.csv")
print(train.shape)
# Out:
# (18399, 6)
# (8000, 5)

# %%
from utils.utility import convert_labels_to_pixel

convert_labels_to_pixel(labels_df)
# Out:
#        x_min  y_min  x_max  y_max                          image_id class
# 0        674    658    745    718  bb929c7dbc4688686a3a985554ca7f1b     0
# 1        541    908    603    946  f3d4aca4eb718586b46d1f7792f622f3     0
# 2        259    433    313    471  6bea25ec4fef4fa26ea2b535d4624f26     0
# 3        464    723    573    804  fc0f7910801c6373f5c78a1ed20042cd     0
# 4        500     64    536     91  9f76a910ba3a542c14a0e2915b261f78     0
# ...      ...    ...    ...    ...                               ...   ...
# 18394    440    139    508    179  759d167851d02deef160190bd177c45d     0
# 18395    610    441    769    503  51439d7d25110390ae7d25378a36cc0e     0
# 18396    714    440   1149   1024  30c02b4d919e92849749f96f4493dff0     0
# 18397    778    185    975    332  c0fb9688d374249e0e954aa948f5d3b2     0
# 18398    189    371    231    422  4ca4a36bc69d962196a2c681a6b49a13     0
#
# [18399 rows x 6 columns]
