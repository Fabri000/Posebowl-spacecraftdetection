# %%
from utils.dataset_converter import DatasetConverter2Coco

# %%
c = DatasetConverter2Coco(original_dataset_path="D:\\file\\Bowl\\DetectionTrack\\Data", converted_dataset_path="D:\\file\\Bowl\\DetectionTrack\\CocoDataset")

# %%
c.convert()
# Out:
# Processing test...
# Processing train...
# Processing val...
