# %%
from utils.utility import get_labels
import pandas as pd

labels_df = get_labels("train")
labels_df.head()
# Out:
#   class     x_center       y_center       width        height  \
# 0     0  0.554296875       0.671875  0.05546875    0.05859375
# 1     0     0.446875   0.9052734375   0.0484375   0.037109375
# 2     0    0.2234375     0.44140625   0.0421875   0.037109375
# 3     0  0.405078125  0.74560546875  0.08515625  0.0791015625
# 4     0    0.4046875  0.07568359375    0.028125  0.0263671875
#
#                            image_id
# 0  bb929c7dbc4688686a3a985554ca7f1b
# 1  f3d4aca4eb718586b46d1f7792f622f3
# 2  6bea25ec4fef4fa26ea2b535d4624f26
# 3  fc0f7910801c6373f5c78a1ed20042cd
# 4  9f76a910ba3a542c14a0e2915b261f78

# %%
from utils.utility import convert_labels_to_pixel

converted = convert_labels_to_pixel(labels_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from utils.utility import convert_labels_to_pixel
# ----> 3 converted = convert_labels_to_pixel(labels_df)
#
# NameError: name 'labels_df' is not defined

# %%
from utils.dataset import SpacecraftDataset

dataset = SpacecraftDataset("train")

# %%
dataset.__getitem__(0)
# Out:
# tensor([[674, 658, 745, 718]])
# (tensor([[[ 16,  16,  18,  ..., 118, 135, 147],
#           [ 11,  12,  14,  ..., 109, 128, 142],
#           [  8,   9,  11,  ..., 108, 127, 142],
#           ...,
#           [  0,   0,   0,  ..., 102, 100, 186],
#           [  0,   0,   0,  ..., 144, 118,  69],
#           [  0,   0,   0,  ..., 101, 137, 152]],
#
#          [[ 55,  55,  57,  ..., 134, 151, 163],
#           [ 50,  51,  53,  ..., 125, 144, 158],
#           [ 47,  48,  50,  ..., 124, 143, 158],
#           ...,
#           [  0,   0,   0,  ..., 120, 116, 203],
#           [  0,   0,   0,  ..., 163, 135,  86],
#           [  0,   0,   0,  ..., 120, 154, 169]],
#
#          [[ 94,  94,  96,  ..., 149, 166, 178],
#           [ 91,  90,  94,  ..., 140, 159, 173],
#           [ 90,  89,  93,  ..., 137, 156, 171],
#           ...,
#           [  0,   0,   0,  ..., 142, 139, 223],
#           [  0,   0,   0,  ..., 180, 153, 104],
# ...
