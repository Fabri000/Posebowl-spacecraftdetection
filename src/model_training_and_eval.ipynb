# %%
import torch
from utils.utility import get_model

# %%
model = get_model("fasterrcnn")
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /home/fabri/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100.0%

# %%
class trainer:
    def __init__(self, model, device):
        self.model = model.to(device)
        self.device = device
    
    def train(self):
        pass
